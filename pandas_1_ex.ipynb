# %% [markdown]
# # Практическое задание №1
# ## Обработка данных в Pandas
#
# В работе используется учебный набор данных о котах:
#
# - `cats_raw.csv` — основная таблица с сырыми данными;
# - `Данные по котам для Pandas.xlsx` — Excel-файл с дополнительными листами `breeds` и `visits`.
#
# ### Правила выполнения
#
# 1. Выполняйте задания последовательно.
# 2. Не изменяйте исходные файлы.
# 3. Для каждого задания используйте отдельную кодовую ячейку.
# 4. Старайтесь использовать средства Pandas, а не циклы Python, если это возможно.
# 5. После выполнения задания оставляйте в ноутбуке вывод, подтверждающий результат.
# 6. Имена переменных выбирайте понятные и содержательные.
#
# Всего: **15 заданий**.

# %% [markdown]
# ## Подготовка
#
# Импортируйте необходимые библиотеки. В дальнейших заданиях предполагается использование `pandas` и, при необходимости, `pathlib`.
#
# > В этой ячейке напишите код импорта библиотек и создайте путь к папке с данными.

# %% [markdown]
# # Задание 1. Загрузка CSV и первичная проверка
#
# Считайте файл `cats_raw.csv` в объект DataFrame.
#
# После загрузки:
#
# - выведите первые 5 строк;
# - определите количество строк и столбцов;
# - выведите список названий столбцов.
#
# ### Ожидаемый результат
#
# Вы должны получить таблицу с исходными данными о котах и убедиться, что она корректно считалась.
#
# > Подсказка: используйте `pd.read_csv()`, `head()`, `shape`, `columns`.

# %%
import pandas as pd
import numpy as np
# import pathlib
cats_raw = pd.read_csv('cats_raw.csv')
cats_raw
cats_raw.columns
cats_raw.info()
cats_raw.dtypes
cats_raw.isna().sum()
(cats_raw.isna().mean() * 100).round(1)
cats_raw.nunique()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cat_id      125 non-null    str
#  1   name        125 non-null    str
#  2   breed       125 non-null    str
#  3   sex         125 non-null    str
#  4   color       118 non-null    str
#  5   birth_date  125 non-null    str
#  6   weight_kg   117 non-null    str
#  7   height_cm   123 non-null    float64
#  8   city        125 non-null    str
#  9   vaccinated  125 non-null    str
#  10  sterilized  125 non-null    str
#  11  owner_id    120 non-null    str
# dtypes: float64(1), str(11)
# memory usage: 25.2 KB
# cat_id        120
# name           29
# breed          17
# sex             2
# color          10
# birth_date    119
# weight_kg      54
# height_cm      17
# city            8
# vaccinated      6
# sterilized      2
# owner_id       81
# dtype: int64

# %% [markdown]
# # Задание 2. Исследование структуры данных
#
# Проведите первичное исследование DataFrame.
#
# Необходимо:
#
# - вывести общую информацию о таблице;
# - определить тип данных каждого столбца;
# - найти столбцы, содержащие пропущенные значения;
# - посчитать количество уникальных значений в каждом столбце.
#
# ### Ожидаемый результат
#
# По итогам задания вы должны понимать:
#
# - какие поля числовые;
# - какие поля строковые;
# - где есть пропуски;
# - какие признаки имеют небольшое число уникальных значений.
#
# > Подсказка: обратите внимание на `info()`, `dtypes`, `isna()`, `nunique()`.

# %% [markdown]
# # Задание 3. Выбор столбцов и строк
#
# Сформируйте несколько выборок из исходного DataFrame.
#
# Нужно получить:
#
# 1. только столбцы `name`, `breed`, `weight_kg`, `city`;
# 2. первые 10 строк только для столбцов `name` и `city`;
# 3. строки с индексами от 5 до 12 включительно и столбцы `cat_id`, `name`, `sex`, `breed`.
#
# ### Требование
#
# Хотя бы в одном случае используйте `loc`, а в другом — `iloc`.
#
# ### Ожидаемый результат
#
# Три отдельных выборки данных.

# %% [markdown]
# # Задание 4. Фильтрация данных
#
# Найдите котов, удовлетворяющих следующим условиям:
#
# 1. живут в Москве;
# 2. являются кошками;
# 3. живут либо в Москве, либо в Новосибирске;
# 4. относятся к одной из трёх выбранных вами пород.
#
# Для последнего пункта используйте `isin()`.
#
# ### Ожидаемый результат
#
# Для каждого условия получите отдельный DataFrame и выведите первые несколько строк.

# %% [markdown]
# # Задание 5. Сортировка
#
# Отсортируйте данные:
#
# 1. по городу в алфавитном порядке;
# 2. по росту `height_cm` по убыванию;
# 3. сначала по городу по возрастанию, затем по росту внутри города по убыванию.
#
# ### Ожидаемый результат
#
# Покажите первые 10 строк каждого результата.

# %% [markdown]
# # Задание 6. Поиск и удаление дубликатов
#
# Исследуйте таблицу на наличие полных дубликатов.
#
# Необходимо:
#
# - посчитать количество полных дубликатов;
# - вывести все строки, участвующие в дублировании;
# - удалить полные дубликаты;
# - проверить размер таблицы после удаления.
#
# ### Важно
#
# Работайте не с исходной таблицей, а с её копией, например `cats_clean`.
#
# ### Ожидаемый результат
#
# После удаления дублей в таблице должно остаться меньше строк, чем в исходной.

# %% [markdown]
# # Задание 7. Очистка строковых значений
#
# Проведите очистку строковых полей.
#
# Для столбца `breed`:
#
# - удалите пробелы в начале и конце строк;
# - приведите текст к единому регистру.
#
# Для столбцов `vaccinated` и `sterilized`:
#
# - удалите лишние пробелы;
# - приведите значения к нижнему регистру.
#
# ### Проверка
#
# После очистки:
#
# - выведите уникальные значения `vaccinated`;
# - выведите уникальные значения `sterilized`;
# - посчитайте количество уникальных пород.
#
# ### Ожидаемый результат
#
# Одинаковые по смыслу значения должны перестать отличаться из-за регистра и пробелов.

# %% [markdown]
# # Задание 8. Очистка веса
#
# Столбец `weight_kg` содержит некорректные для числового типа значения.
#
# Необходимо:
#
# 1. преобразовать столбец во временный строковый тип;
# 2. заменить десятичные запятые на точки;
# 3. преобразовать результат в числовой тип;
# 4. некорректные значения превратить в пропуски;
# 5. вывести тип столбца после преобразования;
# 6. посчитать количество пропусков в нём.
#
# ### Требование
#
# Используйте `pd.to_numeric(..., errors="coerce")`.
#
# ### Ожидаемый результат
#
# `weight_kg` должен стать числовым столбцом.

# %% [markdown]
# # Задание 9. Работа с пропусками
#
# Исследуйте пропуски в очищенной таблице.
#
# Необходимо:
#
# - посчитать число пропусков в каждом столбце;
# - вычислить долю пропусков в процентах;
# - найти медианный вес;
# - создать новый столбец `weight_kg_filled`, в котором пропуски веса заполнены медианой.
#
# ### Важно
#
# Исходный `weight_kg` не заменяйте.
#
# ### Ожидаемый результат
#
# В `weight_kg_filled` не должно остаться пропусков, связанных с весом.

# %% [markdown]
# # Задание 10. Преобразование дат
#
# Преобразуйте столбец `birth_date` в формат даты.
#
# Требования:
#
# - некорректные даты должны превращаться в `NaT`;
# - посчитайте число некорректных или отсутствующих дат после преобразования;
# - создайте столбцы:
#   - `birth_year`;
#   - `birth_month`;
#   - `birth_dayofweek`.
#
# ### Требование
#
# Используйте `pd.to_datetime(..., errors="coerce")`.
#
# ### Ожидаемый результат
#
# В таблице должны появиться новые признаки, извлечённые из даты рождения.

# %% [markdown]
# # Задание 11. Создание новых признаков
#
# Создайте следующие столбцы:
#
# - `weight_g` — вес в граммах;
# - `height_m` — рост в метрах;
# - `is_large` — булев признак, равный `True`, если вес кота не менее 6 кг;
# - `sex_code` — код пола:
#   - `кот` → `M`;
#   - `кошка` → `F`.
#
# ### Требование
#
# Для `sex_code` используйте `map()`.
#
# ### Ожидаемый результат
#
# Выведите первые 10 строк с новыми признаками.

# %% [markdown]
# # Задание 12. Категоризация с apply()
#
# Создайте функцию, которая относит кота к одной из категорий по весу:
#
# - меньше 4 кг → `лёгкий`;
# - от 4 до 6 кг → `средний`;
# - 6 кг и более → `крупный`;
# - если вес неизвестен → `нет данных`.
#
# Примените функцию к столбцу `weight_kg` с помощью `apply()` и сохраните результат в новый столбец `weight_group`.
#
# ### Ожидаемый результат
#
# Выведите количество котов в каждой весовой категории.

# %% [markdown]
# # Задание 13. GroupBy и агрегирование
#
# Проведите анализ котов по городам.
#
# Для каждого города рассчитайте:
#
# - количество котов;
# - средний вес;
# - медианный вес;
# - средний рост.
#
# Назовите столбцы результата:
#
# - `cats_count`;
# - `avg_weight`;
# - `median_weight`;
# - `avg_height`.
#
# Отсортируйте итоговую таблицу по количеству котов по убыванию.
#
# ### Требование
#
# Используйте `groupby()` и `agg()` с именованными агрегациями.

# %% [markdown]
# # Задание 14. Сводная таблица
#
# Создайте сводную таблицу, которая показывает количество котов и кошек в каждом городе.
#
# Требования:
#
# - строки — города;
# - столбцы — пол;
# - значения — количество животных;
# - отсутствующие комбинации заполните нулями.
#
# ### Требование
#
# Используйте `pd.pivot_table()`.
#
# ### Ожидаемый результат
#
# Получите таблицу вида «город × пол».

# %% [markdown]
# # Задание 15. Объединение таблиц и итоговая аналитика
#
# Используйте Excel-файл `Данные по котам для Pandas.xlsx`.
#
# ### Часть 1. Справочник пород
#
# Считайте лист `breeds`.
#
# Подготовьте ключ для объединения так, чтобы написание пород совпадало с очищенным столбцом `breed`.
#
# Объедините таблицу котов со справочником пород.
#
# Требования:
#
# - тип JOIN — `LEFT`;
# - один кот должен сохранить одну строку;
# - используйте контроль `validate="many_to_one"`.
#
# ### Часть 2. Ветеринарные визиты
#
# Считайте лист `visits`.
#
# Преобразуйте `visit_date` в дату.
#
# Для каждого `cat_id` рассчитайте:
#
# - количество визитов;
# - общую стоимость визитов;
# - среднюю стоимость визита;
# - дату последнего визита.
#
# После этого присоедините агрегированные данные о визитах к таблице котов.
#
# ### Часть 3. Итоговый отчёт
#
# Сформируйте таблицу по городам со следующими показателями:
#
# - количество котов;
# - средний вес;
# - общее количество ветеринарных визитов;
# - общие расходы на ветеринарные услуги.
#
# Отсортируйте города по количеству котов по убыванию.
#
# ### Ожидаемый результат
#
# Итоговая аналитическая таблица, объединяющая данные из `cats_raw`, `breeds` и `visits`.

# %% [markdown]
# # Завершение работы
#
# Перед сдачей проверьте:
#
# - все 15 заданий выполнены;
# - все кодовые ячейки запускаются без ошибок;
# - в ноутбуке сохранены результаты выполнения;
# - исходные файлы не изменены;
# - названия переменных понятны;
# - в итоговом задании действительно используются все три таблицы.
#
# ### Дополнительно
#
# Попробуйте ответить на вопрос:
#
# **Какой этап обработки данных оказался наиболее важным для качества итоговой аналитики и почему?**
#
# Ответ можно написать в отдельной Markdown-ячейке ниже.
