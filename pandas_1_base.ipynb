# %% [markdown]
# # Обработка данных в Pandas
#
# Практический ноутбук к модулю **«Обработка данных в Pandas»** программы **«Специалист по большим данным»**.
#
# В ноутбуке используется единый учебный набор данных о котах:
#
# - `cats_raw.csv` — основная «сырая» таблица;
# - `Данные по котам для Pandas.xlsx` — Excel-файл с листами `cats_raw`, `breeds`, `visits`, `README`, `data_dictionary`.
#
# Цель: пройти полный цикл работы с данными — **загрузка → диагностика → очистка → преобразование → анализ → объединение → агрегация → экспорт**.

# %% [markdown]
# ## 1. Импорт библиотек

# %%
import pandas as pd
import numpy as np
from pathlib import Path

print('Pandas:', pd.__version__)
# Out:
# Pandas: 3.0.3

# %% [markdown]
# ## 2. Пути к файлам
#
# Если ноутбук лежит в одной папке с данными, менять ничего не нужно.
# Для запуска в другой среде достаточно изменить `DATA_DIR`.

# %%
DATA_DIR = Path(".")

CSV_PATH = DATA_DIR / "cats_raw.csv"
XLSX_PATH = DATA_DIR / "Данные по котам для Pandas.xlsx"

print("CSV:", CSV_PATH)
print("Excel:", XLSX_PATH)
# Out:
# CSV: cats_raw.csv
# Excel: Данные по котам для Pandas.xlsx

# %% [markdown]
# ## 3. Чтение CSV

# %%
cats = pd.read_csv(CSV_PATH)

cats.head()
# Out:
#    cat_id   name                       breed    sex  color  birth_date  \
# 0  CAT001    Лео                    Мейн-кун    кот  рыжий  2021-11-24
# 1  CAT002    Лео  Британская короткошёрстная  кошка  рыжий  2016-09-04
# 2  CAT003  Злата       Шотландская вислоухая    кот  табби  2024-04-01
# 3  CAT004    Мия                   Сибирская  кошка  табби  2024-09-06
# 4  CAT005   Кира                    Сиамская    кот  серый  2023-09-27
#
#   weight_kg  height_cm             city vaccinated sterilized owner_id
# 0       8.4       37.0            Томск         да         да   OWN001
# 1       4.4       31.0           Москва        Да         нет   OWN006
# 2       6.3       35.0           Москва         ДА         да   OWN011
# 3       5.2       33.0  Санкт-Петербург        нет         да   OWN016
# 4       NaN       29.0     Екатеринбург       Нет         нет   OWN021

# %% [markdown]
# ### Размер таблицы

# %%
cats.shape
# Out:
# (125, 12)

# %% [markdown]
# В исходном CSV должно быть **125 строк и 12 столбцов**.
#
# Посмотрим названия полей.

# %%
cats.columns.tolist()
# Out:
# ['cat_id',
#  'name',
#  'breed',
#  'sex',
#  'color',
#  'birth_date',
#  'weight_kg',
#  'height_cm',
#  'city',
#  'vaccinated',
#  'sterilized',
#  'owner_id']

# %% [markdown]
# ## 4. Чтение Excel

# %%
excel = pd.ExcelFile(XLSX_PATH)

excel.sheet_names
# Out:
# ['README', 'cats_raw', 'breeds', 'visits', 'data_dictionary']

# %% [markdown]
# ### Загружаем отдельные листы

# %%
cats_excel = pd.read_excel(XLSX_PATH, sheet_name='cats_raw')
breeds = pd.read_excel(XLSX_PATH, sheet_name='breeds')
visits = pd.read_excel(XLSX_PATH, sheet_name='visits')

print('cats_raw:', cats_excel.shape)
print('breeds:', breeds.shape)
print('visits:', visits.shape)
# Out:
# cats_raw: (125, 12)
# breeds: (12, 6)
# visits: (210, 7)

# %% [markdown]
# ## 5. Первичное знакомство с DataFrame

# %%
cats.head(n=10)
# Out:
#    cat_id    name                       breed    sex        color  birth_date  \
# 0  CAT001     Лео                    Мейн-кун    кот        рыжий  2021-11-24
# 1  CAT002     Лео  Британская короткошёрстная  кошка        рыжий  2016-09-04
# 2  CAT003   Злата       Шотландская вислоухая    кот        табби  2024-04-01
# 3  CAT004     Мия                   Сибирская  кошка        табби  2024-09-06
# 4  CAT005    Кира                    Сиамская    кот        серый  2023-09-27
# 5  CAT006   Плюша            Канадский сфинкс  кошка  серебристый  2018-09-13
# 6  CAT007  Ириска                 Бенгальская    кот        белый  2018-05-07
# 7  CAT008     Том                  Персидская  кошка       чёрный  2020-10-22
# 8  CAT009    Луна                    Рэгдолл     кот        рыжий  2016-08-13
# 9  CAT010    Ника                 Абиссинская  кошка          NaN  2019-06-26
#
#   weight_kg  height_cm             city vaccinated sterilized owner_id
# 0       8.4       37.0            Томск         да         да   OWN001
# 1       4.4       31.0           Москва        Да         нет   OWN006
# 2       6.3       35.0           Москва         ДА         да   OWN011
# 3       5.2       33.0  Санкт-Петербург        нет         да   OWN016
# 4       NaN       29.0     Екатеринбург       Нет         нет   OWN021
# 5       4.4       30.0            Томск        НЕТ         да   OWN026
# 6       4,9       32.0      Новосибирск         да        нет   OWN031
# 7       3.3       26.0           Казань        Да          да   OWN036
# 8       5.3       33.0            Томск         ДА         да   OWN041
# 9       3.6       29.0       Красноярск        нет        нет   OWN046

# %%
cats.tail(n=10)
# Out:
#      cat_id   name                  breed    sex        color  birth_date  \
# 115  CAT116    Лео             Персидская  кошка        белый  2021-05-09
# 116  CAT117    Лео                Рэгдолл    кот          NaN  2023-07-22
# 117  CAT118   Марс            Абиссинская  кошка        серый  2024-04-06
# 118  CAT119   Тиша        Русская голубая    кот  черепаховый  2024-12-26
# 119  CAT120    Том      Норвежская лесная  кошка      голубой  2021-03-12
# 120  CAT003  Злата  Шотландская вислоухая    кот        табби  2024-04-01
# 121  CAT019   Кира            Бенгальская    кот        рыжий  2024-04-12
# 122  CAT055    Мия            Бенгальская    кот        рыжий  2020-01-04
# 123  CAT078   Тиша       Канадский сфинкс  кошка        табби  2017-03-20
# 124  CAT104   Буся             Персидская  кошка  серебристый  2016-07-15
#
#     weight_kg  height_cm         city vaccinated sterilized owner_id
# 115       5.5       32.0  Новосибирск        Да          да   OWN078
# 116       6.1       35.0       Москва         ДА        нет   OWN083
# 117       4,5       28.0        Томск        нет         да   OWN005
# 118       4.5       30.0        Томск       Нет          да   OWN010
# 119       6.9       37.0       Москва        НЕТ        нет   OWN015
# 120       6.3       35.0       Москва         ДА         да   OWN011
# 121       4.4       30.0  Новосибирск         да         да   OWN008
# 122       6.2       33.0        Томск         да        нет   OWN022
# 123       5.2       33.0        Томск        НЕТ         да   OWN054
# 124       4.3       29.0   Красноярск        Да          да   OWN018

# %% [markdown]
# ### Структура таблицы

# %%
cats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cat_id      125 non-null    str
#  1   name        125 non-null    str
#  2   breed       125 non-null    str
#  3   sex         125 non-null    str
#  4   color       118 non-null    str
#  5   birth_date  125 non-null    str
#  6   weight_kg   117 non-null    str
#  7   height_cm   123 non-null    float64
#  8   city        125 non-null    str
#  9   vaccinated  125 non-null    str
#  10  sterilized  125 non-null    str
#  11  owner_id    120 non-null    str
# dtypes: float64(1), str(11)
# memory usage: 25.2 KB

# %% [markdown]
# ### Типы данных

# %%
cats.dtypes
# Out:
# cat_id            str
# name              str
# breed             str
# sex               str
# color             str
# birth_date        str
# weight_kg         str
# height_cm     float64
# city              str
# vaccinated        str
# sterilized        str
# owner_id          str
# dtype: object

# %% [markdown]
# ### Описательная статистика

# %%
cats.describe()
# Out:
#         height_cm
# count  123.000000
# mean    31.886179
# std      3.383187
# min     25.000000
# 25%     29.500000
# 50%     32.000000
# 75%     34.000000
# max     42.000000

# %% [markdown]
# ### Статистика по строковым столбцам

# %%
cats.describe(include='object')
# Out:
# /var/folders/24/z61d72zx27z5ml8twybhwmm40000gn/T/ipykernel_59565/318644098.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cats.describe(include='object')
#         cat_id  name        breed  sex  color  birth_date weight_kg   city  \
# count      125   125          125  125    118         125       117    125
# unique     120    29           17    2     10         119        54      8
# top     CAT003  Кира  Бенгальская  кот  рыжий  2024-04-01       4.4  Томск
# freq         2    10           12   63     16           2         5     21
#
#        vaccinated sterilized owner_id
# count         125        125      120
# unique          6          2       81
# top            да         да   OWN011
# freq           22         76        3

# %% [markdown]
# ### Количество уникальных значений

# %%
cats.nunique().sort_values()
# Out:
# sex             2
# sterilized      2
# vaccinated      6
# city            8
# color          10
# breed          17
# height_cm      17
# name           29
# weight_kg      54
# owner_id       81
# birth_date    119
# cat_id        120
# dtype: int64

# %% [markdown]
# ## 6. Выбор столбцов

# %%
cats['name'].head()
# Out:
# 0      Лео
# 1      Лео
# 2    Злата
# 3      Мия
# 4     Кира
# Name: name, dtype: str

# %%
cats[['name', 'breed', 'weight_kg', 'city']].head()
# Out:
#     name                       breed weight_kg             city
# 0    Лео                    Мейн-кун       8.4            Томск
# 1    Лео  Британская короткошёрстная       4.4           Москва
# 2  Злата       Шотландская вислоухая       6.3           Москва
# 3    Мия                   Сибирская       5.2  Санкт-Петербург
# 4   Кира                    Сиамская       NaN     Екатеринбург

# %% [markdown]
# ## 7. loc и iloc

# %%
a = [8, 7, 5, 9, 0]
print(a[0:3])
# Out:
# [8, 7, 5]

# %%
cats.loc[0:4]
# Out:
#    cat_id   name                       breed    sex  color  birth_date  \
# 0  CAT001    Лео                    Мейн-кун    кот  рыжий  2021-11-24
# 1  CAT002    Лео  Британская короткошёрстная  кошка  рыжий  2016-09-04
# 2  CAT003  Злата       Шотландская вислоухая    кот  табби  2024-04-01
# 3  CAT004    Мия                   Сибирская  кошка  табби  2024-09-06
# 4  CAT005   Кира                    Сиамская    кот  серый  2023-09-27
#
#   weight_kg  height_cm             city vaccinated sterilized owner_id
# 0       8.4       37.0            Томск         да         да   OWN001
# 1       4.4       31.0           Москва        Да         нет   OWN006
# 2       6.3       35.0           Москва         ДА         да   OWN011
# 3       5.2       33.0  Санкт-Петербург        нет         да   OWN016
# 4       NaN       29.0     Екатеринбург       Нет         нет   OWN021

# %%
cats.iloc[0:4]
# Out:
#    cat_id   name                       breed    sex  color  birth_date  \
# 0  CAT001    Лео                    Мейн-кун    кот  рыжий  2021-11-24
# 1  CAT002    Лео  Британская короткошёрстная  кошка  рыжий  2016-09-04
# 2  CAT003  Злата       Шотландская вислоухая    кот  табби  2024-04-01
# 3  CAT004    Мия                   Сибирская  кошка  табби  2024-09-06
#
#   weight_kg  height_cm             city vaccinated sterilized owner_id
# 0       8.4       37.0            Томск         да         да   OWN001
# 1       4.4       31.0           Москва        Да         нет   OWN006
# 2       6.3       35.0           Москва         ДА         да   OWN011
# 3       5.2       33.0  Санкт-Петербург        нет         да   OWN016

# %% [markdown]
# ## 8. Фильтрация строк

# %%
cats[cats['city'] == 'Москва'].head()
# Out:
#     cat_id    name                       breed    sex        color  \
# 1   CAT002     Лео  Британская короткошёрстная  кошка        рыжий
# 2   CAT003   Злата       Шотландская вислоухая    кот        табби
# 17  CAT018  Персик            Канадский сфинкс  кошка  черепаховый
# 21  CAT022    Граф                 Абиссинская  кошка     кремовый
# 27  CAT028    Граф                   Сибирская  кошка  черепаховый
#
#     birth_date weight_kg  height_cm    city vaccinated sterilized owner_id
# 1   2016-09-04       4.4       31.0  Москва        Да         нет   OWN006
# 2   2024-04-01       6.3       35.0  Москва         ДА         да   OWN011
# 17  31.02.2021       4.0       30.0  Москва        НЕТ         да   OWN003
# 21  2018-03-13       5.3       30.0  Москва        нет        нет   OWN023
# 27  2022-08-31       7.1       35.0  Москва        нет         да   OWN053

# %% [markdown]
# ### Несколько условий

# %%
moscow_female = cats[
    (cats['city'] == 'Москва') &
    (cats['sex'] == 'кошка')
]
moscow_female.head()
# Out:
#    cat_id   name                       breed    sex        color  birth_date  \
# 1  CAT002    Лео  Британская короткошёрстная  кошка        рыжий  2016-09-04
# 2  CAT003  Злата       Шотландская вислоухая    кот        табби  2024-04-01
# 3  CAT004    Мия                   Сибирская  кошка        табби  2024-09-06
# 5  CAT006  Плюша            Канадский сфинкс  кошка  серебристый  2018-09-13
# 7  CAT008    Том                  Персидская  кошка       чёрный  2020-10-22
#
#   weight_kg  height_cm             city vaccinated sterilized owner_id
# 1       4.4       31.0           Москва        Да         нет   OWN006
# 2       6.3       35.0           Москва         ДА         да   OWN011
# 3       5.2       33.0  Санкт-Петербург        нет         да   OWN016
# 5       4.4       30.0            Томск        НЕТ         да   OWN026
# 7       3.3       26.0           Казань        Да          да   OWN036

# %% [markdown]
# ### isin()

# %%
cats[
    (cats['city'] == 'Москва') |
    (cats['city'] == 'Новосибирск') |
    (cats['city'] == 'Томск')
].head()
# Out:
#    cat_id    name                       breed    sex        color  birth_date  \
# 0  CAT001     Лео                    Мейн-кун    кот        рыжий  2021-11-24
# 1  CAT002     Лео  Британская короткошёрстная  кошка        рыжий  2016-09-04
# 2  CAT003   Злата       Шотландская вислоухая    кот        табби  2024-04-01
# 5  CAT006   Плюша            Канадский сфинкс  кошка  серебристый  2018-09-13
# 6  CAT007  Ириска                 Бенгальская    кот        белый  2018-05-07
#
#   weight_kg  height_cm         city vaccinated sterilized owner_id
# 0       8.4       37.0        Томск         да         да   OWN001
# 1       4.4       31.0       Москва        Да         нет   OWN006
# 2       6.3       35.0       Москва         ДА         да   OWN011
# 5       4.4       30.0        Томск        НЕТ         да   OWN026
# 6       4,9       32.0  Новосибирск         да        нет   OWN031

# %%
selected_cities = ['Москва', 'Новосибирск', 'Томск']

cats[cats['city'].isin(selected_cities)].head()
# Out:
#    cat_id    name                       breed    sex        color  birth_date  \
# 0  CAT001     Лео                    Мейн-кун    кот        рыжий  2021-11-24
# 1  CAT002     Лео  Британская короткошёрстная  кошка        рыжий  2016-09-04
# 2  CAT003   Злата       Шотландская вислоухая    кот        табби  2024-04-01
# 5  CAT006   Плюша            Канадский сфинкс  кошка  серебристый  2018-09-13
# 6  CAT007  Ириска                 Бенгальская    кот        белый  2018-05-07
#
#   weight_kg  height_cm         city vaccinated sterilized owner_id
# 0       8.4       37.0        Томск         да         да   OWN001
# 1       4.4       31.0       Москва        Да         нет   OWN006
# 2       6.3       35.0       Москва         ДА         да   OWN011
# 5       4.4       30.0        Томск        НЕТ         да   OWN026
# 6       4,9       32.0  Новосибирск         да        нет   OWN031

# %% [markdown]
# ### query()

# %%
cats.query("city == 'Москва' and sex == 'кошка'").head()
# Out:
#     cat_id    name                       breed    sex        color  \
# 1   CAT002     Лео  Британская короткошёрстная  кошка        рыжий
# 17  CAT018  Персик            Канадский сфинкс  кошка  черепаховый
# 21  CAT022    Граф                 Абиссинская  кошка     кремовый
# 27  CAT028    Граф                   Сибирская  кошка  черепаховый
# 31  CAT032   Алиса                  Персидская  кошка  колор-пойнт
#
#     birth_date   weight_kg  height_cm    city vaccinated sterilized owner_id
# 1   2016-09-04         4.4       31.0  Москва        Да         нет   OWN006
# 17  31.02.2021         4.0       30.0  Москва        НЕТ         да   OWN003
# 21  2018-03-13         5.3       30.0  Москва        нет        нет   OWN023
# 27  2022-08-31         7.1       35.0  Москва        нет         да   OWN053
# 31  2023-08-09  нет данных       29.0  Москва        Да         нет   OWN073

# %% [markdown]
# ## 9. Сортировка

# %%
cats.sort_values('city').head()
# Out:
#     cat_id    name                       breed    sex        color  \
# 4   CAT005    Кира                    Сиамская    кот        серый
# 11  CAT012   Марта           Норвежская лесная  кошка        белый
# 20  CAT021    Кира                     Рэгдолл    кот  черепаховый
# 22  CAT023  Ириска             Русская голубая    кот        белый
# 25  CAT026    Соня  британская короткошёрстная  кошка  колор-пойнт
#
#     birth_date weight_kg  height_cm          city vaccinated sterilized  \
# 4   2023-09-27       NaN       29.0  Екатеринбург       Нет         нет
# 11  2023-04-07       7.8       39.0  Екатеринбург        НЕТ        нет
# 20  2024-05-17       5.0       32.0  Екатеринбург         ДА         да
# 22  2023-10-27       6,2       33.0  Екатеринбург       Нет          да
# 25  2020-12-01       3.9       27.0  Екатеринбург        Да          да
#
#    owner_id
# 4    OWN021
# 11   OWN056
# 20   OWN018
# 22   OWN028
# 25   OWN043

# %%
cats.sort_values(
    ['city', 'height_cm'],
    ascending=[True, False]
).head(10)
# Out:
#     cat_id    name              breed    sex        color  birth_date  \
# 11  CAT012   Марта  Норвежская лесная  кошка        белый  2023-04-07
# 48  CAT049   Алиса           Мейн-кун    кот  серебристый  2025-03-09
# 42  CAT043    Граф        Бенгальская    кот  колор-пойнт  2021-12-02
# 80  CAT081   Оскар            Рэгдолл    кот        серый  2019-06-11
# 83  CAT084    Кузя  Норвежская лесная  кошка  колор-пойнт  2020-01-08
# 22  CAT023  Ириска    Русская голубая    кот        белый  2023-10-27
# 20  CAT021    Кира            Рэгдолл    кот  черепаховый  2024-05-17
# 76  CAT077    Марс           Сиамская    кот     кремовый  2021-04-13
# 96  CAT097    Ника           Мейн-кун    кот  черепаховый  2019-11-25
# 29  CAT030    Кира   Канадский сфинкс  кошка  колор-пойнт  2016-07-06
#
#    weight_kg  height_cm          city vaccinated sterilized owner_id
# 11       7.8       39.0  Екатеринбург        НЕТ        нет   OWN056
# 48       9.1       39.0  Екатеринбург         да         да   OWN075
# 42       7.3       38.0  Екатеринбург         да         да   OWN045
# 80       7.3       38.0  Екатеринбург         ДА         да   OWN069
# 83       7.5       37.0  Екатеринбург        НЕТ         да   OWN001
# 22       6,2       33.0  Екатеринбург       Нет          да   OWN028
# 20       5.0       32.0  Екатеринбург         ДА         да   OWN018
# 76       5.7       32.0  Екатеринбург       Нет         нет   OWN049
# 96       6.3       32.0  Екатеринбург         да        нет   OWN066
# 29       4.8       30.0  Екатеринбург        НЕТ        нет   OWN063

# %% [markdown]
# # Часть II. Очистка данных
#
# Далее создадим отдельную копию таблицы, чтобы исходные данные всегда оставались доступными.

# %%
cats_clean = cats.copy()
cats_clean.shape
# Out:
# (125, 12)

# %% [markdown]
# ## 10. Поиск пропусков

# %%
cats_clean.isna().sum()
# Out:
# cat_id        0
# name          0
# breed         0
# sex           0
# color         7
# birth_date    0
# weight_kg     8
# height_cm     2
# city          0
# vaccinated    0
# sterilized    0
# owner_id      5
# dtype: int64

# %% [markdown]
# ### Доля пропусков в процентах

# %%
cats_clean.isna().mean().mul(100).round(2).sort_values(ascending=False)
# Out:
# weight_kg     6.4
# color         5.6
# owner_id      4.0
# height_cm     1.6
# cat_id        0.0
# name          0.0
# breed         0.0
# sex           0.0
# birth_date    0.0
# city          0.0
# vaccinated    0.0
# sterilized    0.0
# dtype: float64

# %% [markdown]
# ### Строки, в которых отсутствует вес

# %%
cats_clean[cats_clean['weight_kg'].isna()].head()
# Out:
#     cat_id    name            breed    sex        color  birth_date weight_kg  \
# 4   CAT005    Кира         Сиамская    кот        серый  2023-09-27       NaN
# 19  CAT020    Соня       Персидская  кошка     кремовый  2023-12-18       NaN
# 28  CAT029  Ириска         Сиамская    кот  колор-пойнт  2024-09-22       NaN
# 46  CAT047   Злата  Русская голубая    кот        белый  2024-01-09       NaN
# 58  CAT059     Лео  Русская голубая    кот      голубой  2021-04-28       NaN
#
#     height_cm             city vaccinated sterilized owner_id
# 4        29.0     Екатеринбург       Нет         нет   OWN021
# 19       30.0  Санкт-Петербург        Да         нет   OWN013
# 28       28.0  Санкт-Петербург       Нет          да   OWN058
# 46       29.0       Красноярск       Нет         нет   OWN065
# 58       33.0      Новосибирск       Нет          да   OWN042

# %% [markdown]
# ## 11. Дубликаты

# %%
cats_clean.duplicated().sum()
# Out:
# np.int64(5)

# %% [markdown]
# ### Удаляем дубликаты

# %%
cats_clean = cats_clean.drop_duplicates().copy()

cats_clean.shape
# Out:
# (120, 12)

# %% [markdown]
# ## 12. Очистка текстовых значений

# %%
cats_clean['breed'].unique()
# Out:
# <ArrowStringArray>
# [                  'Мейн-кун', 'Британская короткошёрстная',
#       'Шотландская вислоухая',                  'Сибирская',
#                    'Сиамская',           'Канадский сфинкс',
#                 'Бенгальская',                 'Персидская',
#                  '  Рэгдолл ',                'Абиссинская',
#             'Русская голубая',          'Норвежская лесная',
#                     'Рэгдолл', 'британская короткошёрстная',
#               '  Персидская ',                'абиссинская',
#                 '  Мейн-кун ']
# Length: 17, dtype: str

# %% [markdown]
# ### Убираем лишние пробелы

# %%
cats_clean['breed'] = cats_clean['breed'].str.strip()

cats_clean['breed'].unique()
# Out:
# <ArrowStringArray>
# [                  'Мейн-кун', 'Британская короткошёрстная',
#       'Шотландская вислоухая',                  'Сибирская',
#                    'Сиамская',           'Канадский сфинкс',
#                 'Бенгальская',                 'Персидская',
#                     'Рэгдолл',                'Абиссинская',
#             'Русская голубая',          'Норвежская лесная',
#  'британская короткошёрстная',                'абиссинская']
# Length: 14, dtype: str

# %% [markdown]
# ### Нормализуем регистр пород

# %%
cats_clean['breed'] = (
    cats_clean['breed']
    .str.strip()
    .str.lower()
)

cats_clean['breed'].value_counts()
# Out:
# breed
# мейн-кун                      10
# британская короткошёрстная    10
# шотландская вислоухая         10
# сибирская                     10
# сиамская                      10
# канадский сфинкс              10
# бенгальская                   10
# персидская                    10
# рэгдолл                       10
# абиссинская                   10
# русская голубая               10
# норвежская лесная             10
# Name: count, dtype: int64

# %% [markdown]
# ## 13. Нормализация признака vaccinated

# %%
cats_clean['vaccinated'] = (
    cats_clean['vaccinated']
    .str.strip()
    .str.lower()
)

cats_clean['vaccinated'].value_counts(dropna=False)
# Out:
# vaccinated
# да     60
# нет    60
# Name: count, dtype: int64

# %% [markdown]
# ## 14. Очистка веса

# %%
cats_clean['weight_kg'].head(120)
# Out:
# 0      8.4
# 1      4.4
# 2      6.3
# 3      5.2
# 4      NaN
#       ...
# 115    5.5
# 116    6.1
# 117    4,5
# 118    4.5
# 119    6.9
# Name: weight_kg, Length: 120, dtype: str

# %%
cats_clean['weight_kg'] = (
    cats_clean['weight_kg']
    .astype("string")
    .str.strip()
    .str.replace(",", ".", regex=False)
)

cats_clean['weight_kg'].head(120)
# Out:
# 0       8.4
# 1       4.4
# 2       6.3
# 3       5.2
# 4      <NA>
#        ...
# 115     5.5
# 116     6.1
# 117     4.5
# 118     4.5
# 119     6.9
# Name: weight_kg, Length: 120, dtype: string

# %%
cats_clean['weight_kg'] = pd.to_numeric(
    cats_clean['weight_kg'],
    errors='coerce'
)

cats_clean['weight_kg'].dtype
# Out:
# Float64Dtype()

# %%
cats_clean['weight_kg'].head(120)
# Out:
# 0       8.4
# 1       4.4
# 2       6.3
# 3       5.2
# 4      <NA>
#        ...
# 115     5.5
# 116     6.1
# 117     4.5
# 118     4.5
# 119     6.9
# Name: weight_kg, Length: 120, dtype: Float64

# %%
cats_clean['weight_kg'].isna().sum()
# Out:
# np.int64(12)

# %%
median_weight = cats_clean['weight_kg'].median()
cats_clean['weight_kg_filled'] = (
    cats_clean['weight_kg']
    .fillna(median_weight)
)
median_weight
# Out:
# np.float64(5.15)

# %%
cats_clean
# Out:
#      cat_id   name                       breed    sex        color  \
# 0    CAT001    Лео                    мейн-кун    кот        рыжий
# 1    CAT002    Лео  британская короткошёрстная  кошка        рыжий
# 2    CAT003  Злата       шотландская вислоухая    кот        табби
# 3    CAT004    Мия                   сибирская  кошка        табби
# 4    CAT005   Кира                    сиамская    кот        серый
# ..      ...    ...                         ...    ...          ...
# 115  CAT116    Лео                  персидская  кошка        белый
# 116  CAT117    Лео                     рэгдолл    кот          NaN
# 117  CAT118   Марс                 абиссинская  кошка        серый
# 118  CAT119   Тиша             русская голубая    кот  черепаховый
# 119  CAT120    Том           норвежская лесная  кошка      голубой
#
#      birth_date  weight_kg  height_cm             city vaccinated sterilized  \
# 0    2021-11-24        8.4       37.0            Томск         да         да
# 1    2016-09-04        4.4       31.0           Москва         да        нет
# 2    2024-04-01        6.3       35.0           Москва         да         да
# 3    2024-09-06        5.2       33.0  Санкт-Петербург        нет         да
# 4    2023-09-27       <NA>       29.0     Екатеринбург        нет        нет
# ..          ...        ...        ...              ...        ...        ...
# 115  2021-05-09        5.5       32.0      Новосибирск         да         да
# 116  2023-07-22        6.1       35.0           Москва         да        нет
# 117  2024-04-06        4.5       28.0            Томск        нет         да
# 118  2024-12-26        4.5       30.0            Томск        нет         да
# 119  2021-03-12        6.9       37.0           Москва        нет        нет
#
#     owner_id  weight_kg_filled
# 0     OWN001               8.4
# 1     OWN006               4.4
# 2     OWN011               6.3
# 3     OWN016               5.2
# 4     OWN021              5.15
# ..       ...               ...
# 115   OWN078               5.5
# 116   OWN083               6.1
# 117   OWN005               4.5
# 118   OWN010               4.5
# 119   OWN015               6.9
#
# [120 rows x 13 columns]

# %% [markdown]
# ## 15. Преобразование дат

# %%
cats_clean['birth_date'].head(120)
# Out:
# 0      2021-11-24
# 1      2016-09-04
# 2      2024-04-01
# 3      2024-09-06
# 4      2023-09-27
#           ...
# 115    2021-05-09
# 116    2023-07-22
# 117    2024-04-06
# 118    2024-12-26
# 119    2021-03-12
# Name: birth_date, Length: 120, dtype: str

# %%
cats_clean['birth_date'] = pd.to_datetime(
    cats_clean['birth_date'],
    errors='coerce',
    dayfirst=True
)
# Out:
# /var/folders/24/z61d72zx27z5ml8twybhwmm40000gn/T/ipykernel_59565/3921264282.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   cats_clean['birth_date'] = pd.to_datetime(

# %%
cats_clean['birth_date'].head(120)
# Out:
# 0     2021-11-24
# 1     2016-09-04
# 2     2024-04-01
# 3     2024-09-06
# 4     2023-09-27
#          ...
# 115   2021-05-09
# 116   2023-07-22
# 117   2024-04-06
# 118   2024-12-26
# 119   2021-03-12
# Name: birth_date, Length: 120, dtype: datetime64[us]

# %%
cats_clean['birth_year'] = cats_clean['birth_date'].dt.year
cats_clean['birth_month'] = cats_clean['birth_date'].dt.month
cats_clean['birth_dayofweek'] = cats_clean['birth_date'].dt.dayofweek

cats_clean[['name', 'birth_date', 'birth_year', 'birth_month', 'birth_dayofweek']].head(10)
# Out:
#      name birth_date  birth_year  birth_month  birth_dayofweek
# 0     Лео 2021-11-24      2021.0         11.0              2.0
# 1     Лео 2016-09-04      2016.0          9.0              6.0
# 2   Злата 2024-04-01      2024.0          4.0              0.0
# 3     Мия 2024-09-06      2024.0          9.0              4.0
# 4    Кира 2023-09-27      2023.0          9.0              2.0
# 5   Плюша 2018-09-13      2018.0          9.0              3.0
# 6  Ириска 2018-05-07      2018.0          5.0              0.0
# 7     Том 2020-10-22      2020.0         10.0              3.0
# 8    Луна 2016-08-13      2016.0          8.0              5.0
# 9    Ника 2019-06-26      2019.0          6.0              2.0

# %% [markdown]
# ## 16. Создание новых признаков

# %%
cats_clean['weight_g'] = cats_clean['weight_kg'] * 1000

cats_clean[['weight_g', 'weight_kg']]
# Out:
#      weight_g  weight_kg
# 0      8400.0        8.4
# 1      4400.0        4.4
# 2      6300.0        6.3
# 3      5200.0        5.2
# 4        <NA>       <NA>
# ..        ...        ...
# 115    5500.0        5.5
# 116    6100.0        6.1
# 117    4500.0        4.5
# 118    4500.0        4.5
# 119    6900.0        6.9
#
# [120 rows x 2 columns]

# %%
cats_clean["is_large"] = cats_clean['weight_kg'] >= 6

cats_clean[['is_large', 'weight_kg']]
# Out:
#      is_large  weight_kg
# 0        True        8.4
# 1       False        4.4
# 2        True        6.3
# 3       False        5.2
# 4        <NA>       <NA>
# ..        ...        ...
# 115     False        5.5
# 116      True        6.1
# 117     False        4.5
# 118     False        4.5
# 119      True        6.9
#
# [120 rows x 2 columns]

# %% [markdown]
# ## 17. map()

# %%
cats_clean['sex_code'] = cats_clean['sex'].map({
    'кот':'M',
    'кошка': 'F'
})

cats_clean[['sex', 'sex_code']]
# Out:
#        sex sex_code
# 0      кот        M
# 1    кошка        F
# 2      кот        M
# 3    кошка        F
# 4      кот        M
# ..     ...      ...
# 115  кошка        F
# 116    кот        M
# 117  кошка        F
# 118    кот        M
# 119  кошка        F
#
# [120 rows x 2 columns]

# %% [markdown]
# ## 18. apply()

# %%
def weight_category(weight):
    if pd.isna(weight):
        return 'нет данных'
    if weight < 4:
        return 'легкий'
    elif weight < 6:
        return 'средний'
    else:
        return 'крупный'

cats_clean['weight_category'] = cats_clean['weight_kg'].apply(weight_category)
cats_clean['weight_category'].value_counts()
# Out:
# weight_category
# средний       54
# крупный       35
# легкий        19
# нет данных    12
# Name: count, dtype: int64

# %% [markdown]
# ## 19. Векторизация вместо цикла
#
# Для простых операций предпочтительнее использовать векторизованные выражения Pandas.

# %%
cats_clean['height_m'] = cats_clean['height_cm'] / 100

cats_clean[['height_m', 'height_cm']]
# Out:
#      height_m  height_cm
# 0        0.37       37.0
# 1        0.31       31.0
# 2        0.35       35.0
# 3        0.33       33.0
# 4        0.29       29.0
# ..        ...        ...
# 115      0.32       32.0
# 116      0.35       35.0
# 117      0.28       28.0
# 118      0.30       30.0
# 119      0.37       37.0
#
# [120 rows x 2 columns]

# %% [markdown]
# # Часть III. Анализ данных

# %% [markdown]
# ## 20. value_counts()

# %%
cats_clean['city'].value_counts()
# Out:
# city
# Москва             20
# Томск              19
# Екатеринбург       16
# Новосибирск        16
# Санкт-Петербург    15
# Красноярск         13
# Казань             12
# Омск                9
# Name: count, dtype: int64

# %% [markdown]
# ### Нормализованные доли

# %%
cats_clean['city'].value_counts(normalize=True).mul(100).round(2)
# Out:
# city
# Москва             16.67
# Томск              15.83
# Екатеринбург       13.33
# Новосибирск        13.33
# Санкт-Петербург    12.50
# Красноярск         10.83
# Казань             10.00
# Омск                7.50
# Name: proportion, dtype: float64

# %% [markdown]
# ## 21. Базовые агрегаты

# %%
cats_clean['weight_kg'].agg([
    'count', 'mean', 'median', 'min', 'max'
])
# Out:
# count     108.000000
# mean        5.394444
# median      5.150000
# min         2.900000
# max         9.200000
# Name: weight_kg, dtype: float64

# %% [markdown]
# ## 22. GroupBy

# %%
cats_clean.groupby('city')['weight_kg'].median().sort_values(ascending=False)
# Out:
# city
# Екатеринбург       5.95
# Омск                5.4
# Томск               5.3
# Новосибирск         5.2
# Москва              5.2
# Красноярск          5.1
# Санкт-Петербург     4.9
# Казань              4.6
# Name: weight_kg, dtype: Float64

# %%
print(0.1 + 0.1 == 0.2)
print(0.1+0.1+0.1)
# Out:
# True
# 0.30000000000000004

# %% [markdown]
# ### Несколько показателей

# %%
city_stats = (
    cats_clean
    .groupby('city')
    .agg(
        cats_count = ('cat_id', 'count'),
        avg_weight = ('weight_kg', 'mean'),
        median_weight = ('weight_kg', 'median'),
        avg_height = ('height_cm', 'mean'),
    )
    .round(2)
    .sort_values('cats_count', ascending=False)
)

city_stats
# Out:
#                  cats_count  avg_weight  median_weight  avg_height
# city
# Москва                   20        5.24            5.2       31.58
# Томск                    19         5.6            5.3       32.68
# Екатеринбург             16        5.98           5.95       32.62
# Новосибирск              16        5.46            5.2       31.67
# Санкт-Петербург          15        5.06            4.9       31.60
# Красноярск               13         5.3            5.1       31.23
# Казань                   12        4.72            4.6       30.58
# Омск                      9        5.64            5.4       33.00

# %% [markdown]
# ## 23. GroupBy по нескольким полям

# %%
(
    cats_clean
    .groupby(['city', 'sex'])
    .agg(
        cats_count = ('cat_id', 'count'),
        avg_weight = ('weight_kg', 'mean')
    )
    .head(10).round(2)
)
# Out:
#                     cats_count  avg_weight
# city         sex
# Екатеринбург кот            11        6.13
#              кошка           5         5.7
# Казань       кот             4         4.1
#              кошка           8        5.07
# Красноярск   кот             5        4.88
#              кошка           8        5.54
# Москва       кот             3        6.17
#              кошка          17        5.06
# Новосибирск  кот            10        5.46
#              кошка           6        5.46

# %% [markdown]
# ## 24. pivot_table()

# %%
city_sex_pivot = pd.pivot_table(
    cats_clean,
    index='city',
    columns='sex',
    values='cat_id',
    aggfunc='count',
    fill_value=0
)

# %%
city_sex_pivot
# Out:
# sex              кот  кошка
# city
# Екатеринбург      11      5
# Казань             4      8
# Красноярск         5      8
# Москва             3     17
# Новосибирск       10      6
# Омск               6      3
# Санкт-Петербург    9      6
# Томск             12      7

# %% [markdown]
# ## 25. Справочник пород

# %%
breeds.head()
# Out:
#                         breed          origin    coat_type  \
# 0                    Мейн-кун             США  полудлинная
# 1  Британская короткошёрстная  Великобритания     короткая
# 2       Шотландская вислоухая  Великобритания     короткая
# 3                   Сибирская          Россия  полудлинная
# 4                    Сиамская         Таиланд     короткая
#
#    typical_weight_min_kg  typical_weight_max_kg  typical_lifespan_years
# 0                    5.0                    9.0                      13
# 1                    4.0                    8.0                      14
# 2                    3.0                    6.0                      14
# 3                    4.0                    8.0                      15
# 4                    3.0                    5.5                      16

# %%
breeds.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   breed                   12 non-null     str
#  1   origin                  12 non-null     str
#  2   coat_type               12 non-null     str
#  3   typical_weight_min_kg   12 non-null     float64
#  4   typical_weight_max_kg   12 non-null     float64
#  5   typical_lifespan_years  12 non-null     int64
# dtypes: float64(2), int64(1), str(3)
# memory usage: 1.4 KB

# %%
breeds_clean = breeds.copy()

breeds_clean['breed_key'] = (
    breeds_clean['breed']
    .str.strip()
    .str.lower()
)

cats_clean['breed_key'] = (
    cats_clean['breed']
    .str.strip()
    .str.lower()
)

breeds_clean.head()
# Out:
#                         breed          origin    coat_type  \
# 0                    Мейн-кун             США  полудлинная
# 1  Британская короткошёрстная  Великобритания     короткая
# 2       Шотландская вислоухая  Великобритания     короткая
# 3                   Сибирская          Россия  полудлинная
# 4                    Сиамская         Таиланд     короткая
#
#    typical_weight_min_kg  typical_weight_max_kg  typical_lifespan_years  \
# 0                    5.0                    9.0                      13
# 1                    4.0                    8.0                      14
# 2                    3.0                    6.0                      14
# 3                    4.0                    8.0                      15
# 4                    3.0                    5.5                      16
#
#                     breed_key
# 0                    мейн-кун
# 1  британская короткошёрстная
# 2       шотландская вислоухая
# 3                   сибирская
# 4                    сиамская

# %% [markdown]
# ## 26. merge(): cats + breeds

# %%
cats_with_breeds = cats_clean.merge(
    breeds_clean,
    on = 'breed_key',
    how='left',
    validate='many_to_one',
    suffixes=("", "_ref")
)

cats_with_breeds
# Out:
#      cat_id   name                       breed    sex        color birth_date  \
# 0    CAT001    Лео                    мейн-кун    кот        рыжий 2021-11-24
# 1    CAT002    Лео  британская короткошёрстная  кошка        рыжий 2016-09-04
# 2    CAT003  Злата       шотландская вислоухая    кот        табби 2024-04-01
# 3    CAT004    Мия                   сибирская  кошка        табби 2024-09-06
# 4    CAT005   Кира                    сиамская    кот        серый 2023-09-27
# ..      ...    ...                         ...    ...          ...        ...
# 115  CAT116    Лео                  персидская  кошка        белый 2021-05-09
# 116  CAT117    Лео                     рэгдолл    кот          NaN 2023-07-22
# 117  CAT118   Марс                 абиссинская  кошка        серый 2024-04-06
# 118  CAT119   Тиша             русская голубая    кот  черепаховый 2024-12-26
# 119  CAT120    Том           норвежская лесная  кошка      голубой 2021-03-12
#
#      weight_kg  height_cm             city vaccinated  ... sex_code  \
# 0          8.4       37.0            Томск         да  ...        M
# 1          4.4       31.0           Москва         да  ...        F
# 2          6.3       35.0           Москва         да  ...        M
# 3          5.2       33.0  Санкт-Петербург        нет  ...        F
# 4         <NA>       29.0     Екатеринбург        нет  ...        M
# ..         ...        ...              ...        ...  ...      ...
# 115        5.5       32.0      Новосибирск         да  ...        F
# 116        6.1       35.0           Москва         да  ...        M
# 117        4.5       28.0            Томск        нет  ...        F
# 118        4.5       30.0            Томск        нет  ...        M
# 119        6.9       37.0           Москва        нет  ...        F
#
#     weight_category  height_m                   breed_key  \
# 0           крупный      0.37                    мейн-кун
# 1           средний      0.31  британская короткошёрстная
# 2           крупный      0.35       шотландская вислоухая
# 3           средний      0.33                   сибирская
# 4        нет данных      0.29                    сиамская
# ..              ...       ...                         ...
# 115         средний      0.32                  персидская
# 116         крупный      0.35                     рэгдолл
# 117         средний      0.28                 абиссинская
# 118         средний      0.30             русская голубая
# 119         крупный      0.37           норвежская лесная
#
#                       breed_ref          origin    coat_type  \
# 0                      Мейн-кун             США  полудлинная
# 1    Британская короткошёрстная  Великобритания     короткая
# 2         Шотландская вислоухая  Великобритания     короткая
# 3                     Сибирская          Россия  полудлинная
# 4                      Сиамская         Таиланд     короткая
# ..                          ...             ...          ...
# 115                  Персидская            Иран      длинная
# 116                     Рэгдолл             США  полудлинная
# 117                 Абиссинская         Эфиопия     короткая
# 118             Русская голубая          Россия     короткая
# 119           Норвежская лесная        Норвегия  полудлинная
#
#      typical_weight_min_kg typical_weight_max_kg typical_lifespan_years
# 0                      5.0                   9.0                     13
# 1                      4.0                   8.0                     14
# 2                      3.0                   6.0                     14
# 3                      4.0                   8.0                     15
# 4                      3.0                   5.5                     16
# ..                     ...                   ...                    ...
# 115                    3.0                   6.0                     14
# 116                    4.5                   9.0                     15
# 117                    3.0                   5.5                     15
# 118                    3.0                   6.0                     16
# 119                    4.0                   9.0                     14
#
# [120 rows x 28 columns]

# %% [markdown]
# ## 27. Таблица ветеринарных визитов

# %%
visits.head()
# Out:
#   visit_id  cat_id visit_date                   reason      clinic  cost_rub  \
# 0  VIS0001  CAT001 2026-08-09  профилактический осмотр     Айболит       NaN
# 1  VIS0002  CAT001 2026-06-17             анализ крови  Белый клык    1641.0
# 2  VIS0003  CAT001 2026-04-25             дерматология  Доктор Вет    2182.0
# 3  VIS0004  CAT002 2026-07-23               вакцинация   Кот и пёс    1479.0
# 4  VIS0005  CAT003 2026-07-06             анализ крови  Белый клык    1858.0
#
#    follow_up_days
# 0            14.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
visits.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   visit_id        210 non-null    str
#  1   cat_id          210 non-null    str
#  2   visit_date      210 non-null    datetime64[us]
#  3   reason          210 non-null    str
#  4   clinic          210 non-null    str
#  5   cost_rub        202 non-null    float64
#  6   follow_up_days  66 non-null     float64
# dtypes: datetime64[us](1), float64(2), str(4)
# memory usage: 23.6 KB

# %%
visits_clean = visits.copy()

visits_clean['visit_date'] = pd.to_datetime(
    visits_clean['visit_date'],
    errors="coerce"
)

visits_clean['visit_date'].min(), visits_clean['visit_date'].max()
# Out:
# (Timestamp('2025-06-08 00:00:00'), Timestamp('2026-08-09 00:00:00'))

# %% [markdown]
# ## 28. merge(): cats + visits

# %%
cats_visits = cats_clean.merge(
    visits_clean,
    on='cat_id',
    how='left',
    validate='one_to_many'
)

print('Коты:', cats_clean.shape)
print('Визиты:', visits_clean.shape)
print('После JOIN:', cats_visits.shape)
# Out:
# Коты: (120, 22)
# Визиты: (210, 7)
# После JOIN: (210, 28)

# %% [markdown]
# ## 29. Количество визитов на кота

# %%
visits_per_cat = (
    visits_clean
    .groupby('cat_id')
    .agg(
        visits_count=('visit_id', 'count'),
        total_cost=('cost_rub', 'sum'),
        avg_cost=('cost_rub', 'mean'),
        last_visit=('visit_date', 'max')
    )
    .reset_index()
)

visits_per_cat.head()
# Out:
#    cat_id  visits_count  total_cost  avg_cost last_visit
# 0  CAT001             3      3823.0    1911.5 2026-08-09
# 1  CAT002             1      1479.0    1479.0 2026-07-23
# 2  CAT003             1      1858.0    1858.0 2026-07-06
# 3  CAT004             2      5015.0    2507.5 2026-06-19
# 4  CAT005             3      9471.0    3157.0 2026-06-02

# %% [markdown]
# ### Добавляем агрегаты визитов к котам

# %%
cats_analytics = cats_with_breeds.merge(
    visits_per_cat,
    on='cat_id',
    how='left',
    validate='one_to_one'
)

# %%
cats_analytics.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cat_id                  120 non-null    str
#  1   name                    120 non-null    str
#  2   breed                   120 non-null    str
#  3   sex                     120 non-null    str
#  4   color                   113 non-null    str
#  5   birth_date              117 non-null    datetime64[us]
#  6   weight_kg               108 non-null    Float64
#  7   height_cm               118 non-null    float64
#  8   city                    120 non-null    str
#  9   vaccinated              120 non-null    str
#  10  sterilized              120 non-null    str
#  11  owner_id                115 non-null    str
#  12  weight_kg_filled        120 non-null    Float64
#  13  birth_year              117 non-null    float64
#  14  birth_month             117 non-null    float64
#  15  birth_dayofweek         117 non-null    float64
#  16  weight_g                108 non-null    Float64
#  17  is_large                108 non-null    boolean
#  18  sex_code                120 non-null    str
#  19  weight_category         120 non-null    str
#  20  height_m                118 non-null    float64
#  21  breed_key               120 non-null    str
#  22  breed_ref               120 non-null    str
#  23  origin                  120 non-null    str
#  24  coat_type               120 non-null    str
#  25  typical_weight_min_kg   120 non-null    float64
#  26  typical_weight_max_kg   120 non-null    float64
#  27  typical_lifespan_years  120 non-null    int64
#  28  visits_count            120 non-null    int64
#  29  total_cost              120 non-null    float64
#  30  avg_cost                118 non-null    float64
#  31  last_visit              120 non-null    datetime64[us]
# dtypes: Float64(3), boolean(1), datetime64[us](2), float64(9), int64(2), str(15)
# memory usage: 52.7 KB

# %%
cats_analytics['visits_count'] = cats_analytics['visits_count'].fillna(0).astype('int')
cats_analytics['total_cost'] = cats_analytics['total_cost'].fillna(0)

cats_analytics.head()
# Out:
#    cat_id   name                       breed    sex  color birth_date  \
# 0  CAT001    Лео                    мейн-кун    кот  рыжий 2021-11-24
# 1  CAT002    Лео  британская короткошёрстная  кошка  рыжий 2016-09-04
# 2  CAT003  Злата       шотландская вислоухая    кот  табби 2024-04-01
# 3  CAT004    Мия                   сибирская  кошка  табби 2024-09-06
# 4  CAT005   Кира                    сиамская    кот  серый 2023-09-27
#
#    weight_kg  height_cm             city vaccinated  ...  \
# 0        8.4       37.0            Томск         да  ...
# 1        4.4       31.0           Москва         да  ...
# 2        6.3       35.0           Москва         да  ...
# 3        5.2       33.0  Санкт-Петербург        нет  ...
# 4       <NA>       29.0     Екатеринбург        нет  ...
#
#                     breed_ref          origin    coat_type  \
# 0                    Мейн-кун             США  полудлинная
# 1  Британская короткошёрстная  Великобритания     короткая
# 2       Шотландская вислоухая  Великобритания     короткая
# 3                   Сибирская          Россия  полудлинная
# 4                    Сиамская         Таиланд     короткая
#
#    typical_weight_min_kg  typical_weight_max_kg  typical_lifespan_years  \
# 0                    5.0                    9.0                      13
# 1                    4.0                    8.0                      14
# 2                    3.0                    6.0                      14
# 3                    4.0                    8.0                      15
# 4                    3.0                    5.5                      16
#
#    visits_count  total_cost avg_cost last_visit
# 0             3      3823.0   1911.5 2026-08-09
# 1             1      1479.0   1479.0 2026-07-23
# 2             1      1858.0   1858.0 2026-07-06
# 3             2      5015.0   2507.5 2026-06-19
# 4             3      9471.0   3157.0 2026-06-02
#
# [5 rows x 32 columns]

# %%
cats_analytics
# Out:
#      cat_id   name                       breed    sex        color birth_date  \
# 0    CAT001    Лео                    мейн-кун    кот        рыжий 2021-11-24
# 1    CAT002    Лео  британская короткошёрстная  кошка        рыжий 2016-09-04
# 2    CAT003  Злата       шотландская вислоухая    кот        табби 2024-04-01
# 3    CAT004    Мия                   сибирская  кошка        табби 2024-09-06
# 4    CAT005   Кира                    сиамская    кот        серый 2023-09-27
# ..      ...    ...                         ...    ...          ...        ...
# 115  CAT116    Лео                  персидская  кошка        белый 2021-05-09
# 116  CAT117    Лео                     рэгдолл    кот          NaN 2023-07-22
# 117  CAT118   Марс                 абиссинская  кошка        серый 2024-04-06
# 118  CAT119   Тиша             русская голубая    кот  черепаховый 2024-12-26
# 119  CAT120    Том           норвежская лесная  кошка      голубой 2021-03-12
#
#      weight_kg  height_cm             city vaccinated  ...  \
# 0          8.4       37.0            Томск         да  ...
# 1          4.4       31.0           Москва         да  ...
# 2          6.3       35.0           Москва         да  ...
# 3          5.2       33.0  Санкт-Петербург        нет  ...
# 4         <NA>       29.0     Екатеринбург        нет  ...
# ..         ...        ...              ...        ...  ...
# 115        5.5       32.0      Новосибирск         да  ...
# 116        6.1       35.0           Москва         да  ...
# 117        4.5       28.0            Томск        нет  ...
# 118        4.5       30.0            Томск        нет  ...
# 119        6.9       37.0           Москва        нет  ...
#
#                       breed_ref          origin    coat_type  \
# 0                      Мейн-кун             США  полудлинная
# 1    Британская короткошёрстная  Великобритания     короткая
# 2         Шотландская вислоухая  Великобритания     короткая
# 3                     Сибирская          Россия  полудлинная
# 4                      Сиамская         Таиланд     короткая
# ..                          ...             ...          ...
# 115                  Персидская            Иран      длинная
# 116                     Рэгдолл             США  полудлинная
# 117                 Абиссинская         Эфиопия     короткая
# 118             Русская голубая          Россия     короткая
# 119           Норвежская лесная        Норвегия  полудлинная
#
#      typical_weight_min_kg  typical_weight_max_kg  typical_lifespan_years  \
# 0                      5.0                    9.0                      13
# 1                      4.0                    8.0                      14
# 2                      3.0                    6.0                      14
# 3                      4.0                    8.0                      15
# 4                      3.0                    5.5                      16
# ..                     ...                    ...                     ...
# 115                    3.0                    6.0                      14
# 116                    4.5                    9.0                      15
# 117                    3.0                    5.5                      15
# 118                    3.0                    6.0                      16
# 119                    4.0                    9.0                      14
#
#      visits_count  total_cost avg_cost last_visit
# 0               3      3823.0   1911.5 2026-08-09
# 1               1      1479.0   1479.0 2026-07-23
# 2               1      1858.0   1858.0 2026-07-06
# 3               2      5015.0   2507.5 2026-06-19
# 4               3      9471.0   3157.0 2026-06-02
# ..            ...         ...      ...        ...
# 115             1      9085.0   9085.0 2025-12-17
# 116             3      2751.0   1375.5 2025-11-30
# 117             2     11327.0   5663.5 2025-11-13
# 118             1      1322.0   1322.0 2025-10-27
# 119             1      1701.0   1701.0 2025-10-10
#
# [120 rows x 32 columns]

# %% [markdown]
# ## 30. Анализ расходов по городам

# %%
(
    cats_analytics
    .groupby('city')
    .agg(
        cats=('cat_id', 'count'),
        visits=('visits_count', 'sum'),
        total_cost=('total_cost', 'sum'),
        avg_cost_per_cat=('total_cost', 'mean')
    )
    .sort_values("total_cost", ascending=False)
).round(2)
# Out:
#                  cats  visits  total_cost  avg_cost_per_cat
# city
# Томск              19      38    218112.0          11479.58
# Новосибирск        16      29    170481.0          10655.06
# Екатеринбург       16      32    156341.0           9771.31
# Санкт-Петербург    15      28    146244.0           9749.60
# Красноярск         13      25    141345.0          10872.69
# Москва             20      27    118194.0           5909.70
# Казань             12      16     89007.0           7417.25
# Омск                9      15     77763.0           8640.33

# %% [markdown]
# ## 31. Анализ причин визитов

# %%
visits_clean['reason'].value_counts()
# Out:
# reason
# анализ крови               50
# профилактический осмотр    40
# дерматология               40
# контроль веса              40
# вакцинация                 20
# стоматология               20
# Name: count, dtype: int64

# %% [markdown]
# ## 32. Работа с временными данными

# %%
visits_clean['visit_year'] = visits_clean['visit_date'].dt.year
visits_clean['visit_month'] = visits_clean['visit_date'].dt.to_period('M')

# %%
monthly_visits =(
    visits_clean
    .groupby('visit_month')
    .agg(
        visits=('visit_id', 'count'),
        total_cost=('cost_rub', 'sum')
    )
)

monthly_visits
# Out:
#              visits  total_cost
# visit_month
# 2025-06           9     37012.0
# 2025-07          14     65186.0
# 2025-08          13     73927.0
# 2025-09          14    102932.0
# 2025-10          18    119373.0
# 2025-11          15    113361.0
# 2025-12          15    110825.0
# 2026-01          14     89163.0
# 2026-02          16     81661.0
# 2026-03          16     85612.0
# 2026-04          17     71479.0
# 2026-05          15     58615.0
# 2026-06          15     47969.0
# 2026-07          16     54539.0
# 2026-08           3      5833.0

# %% [markdown]
# # Часть IV. Полезные практические приёмы

# %% [markdown]
# ## 33. rename()

# %%
example = cats_clean.rename(
    columns={
        "cat_id": "id",
        "weight_kg": 'weight'
    }
)

example[['id', 'name', 'weight']].head()
# Out:
#        id   name  weight
# 0  CAT001    Лео     8.4
# 1  CAT002    Лео     4.4
# 2  CAT003  Злата     6.3
# 3  CAT004    Мия     5.2
# 4  CAT005   Кира    <NA>

# %% [markdown]
# ## 34. assign()

# %%
(
    cats_clean
    .assign(
        weight_g=lambda df: df['weight_kg'] * 1000,
        height_m=lambda df: df['height_cm'] / 100,
    )
    [['name', 'weight_g', 'height_m']]
    .head()
)
# Out:
#     name  weight_g  height_m
# 0    Лео    8400.0      0.37
# 1    Лео    4400.0      0.31
# 2  Злата    6300.0      0.35
# 3    Мия    5200.0      0.33
# 4   Кира      <NA>      0.29

# %% [markdown]
# ## 35. method chaining

# %%
moscow_stats = (
    cats_clean
    .query("city == 'Москва'")
    .dropna(subset=['weight_kg'])
    .groupby('breed_key')
    .agg(
        cats=('cat_id', 'count'),
        avg_weight=('weight_kg', 'mean')
    )
    .sort_values('cats', ascending=False)
)

moscow_stats
# Out:
#                             cats  avg_weight
# breed_key
# абиссинская                    3    3.733333
# канадский сфинкс               3         4.2
# норвежская лесная              3         6.7
# британская короткошёрстная     2         4.7
# персидская                     2         4.7
# сибирская                      2         6.6
# русская голубая                1         6.1
# рэгдолл                        1         6.1
# шотландская вислоухая          1         6.3

# %% [markdown]
# ## 36. Проверки качества данных

# %% [markdown]
# ### Проверка диапазонов

# %% [markdown]
# ## 37. Экспорт результата

# %% [markdown]
# # Часть V. Итоговый pipeline
#
# Ниже — компактная версия полного сценария, которую можно адаптировать под реальные проекты.

# %% [markdown]
# ## Итоговая аналитическая таблица

# %% [markdown]
# ## Что изучено
#
# В этом ноутбуке показаны:
#
# - `read_csv()` и `read_excel()`;
# - `Series`, `DataFrame`, `Index`;
# - `head()`, `tail()`, `sample()`, `info()`, `describe()`;
# - выбор столбцов, `loc`, `iloc`;
# - фильтрация, `isin()`, `query()`;
# - сортировка;
# - строковые методы `.str`;
# - пропуски и дубликаты;
# - `to_numeric()` и `to_datetime()`;
# - создание новых признаков;
# - `map()` и `apply()`;
# - `value_counts()`;
# - `groupby()` и `agg()`;
# - `pivot_table()`;
# - `merge()` для `many-to-one` и `one-to-many`;
# - анализ временных данных;
# - method chaining;
# - проверки качества;
# - экспорт результатов.
#
# Ноутбук можно использовать как основу для практического занятия или лабораторной работы.
